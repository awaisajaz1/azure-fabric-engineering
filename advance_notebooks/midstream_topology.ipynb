# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.sql("SELECT * FROM earthquakes_lakehouse.earthquake_events_gold LIMIT 100")
display(df)
# Out:
# StatementMeta(, bdf0c4f1-3e0a-4c22-b1fd-8e6376c5bbc3, 39, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b9befc91-7174-4399-8f8e-35a3af20d822)

# %% [markdown]
# Method: Save the Class as a Python File in Lakehouse
# The best way to reuse the class across multiple Fabric notebooks is to save it in Lakehouse Files.
#
# 📌 Step 1: Save window_class.py in Fabric Lakehouse
# Go to Fabric → Lakehouse → Files.
# Create a folder named py_libs.
# Upload a file called window_class.py containing

# %%
import os
print(os.listdir("/lakehouse/default/Files/python_libs"))
# Out:
# StatementMeta(, bdf0c4f1-3e0a-4c22-b1fd-8e6376c5bbc3, 36, Finished, Available, Finished)
# ['window_class.py']

# %%
import sys
sys.path.append("/lakehouse/default/Files/python_libs") 

from windows_class import Rankers  # Import the class
# df = spark.createDataFrame([(1, "A", 100), (2, "B", 200)], ["id", "group", "value"])
rank_processor = Rankers(df)


# df_with_dense_rank = dense_ranks.apply_dense_rank(partition_by=["group"], order_by=["value"])
# df_with_dense_rank.show()
# Out:
# StatementMeta(, bdf0c4f1-3e0a-4c22-b1fd-8e6376c5bbc3, 41, Finished, Available, Finished)

# %% [markdown]
# ## Dense Rank

# %%
df_with_dr = rank_processor.apply_dense_rank(partition_by=["country_name"], order_by=["magnitude"])
display(df_with_dr)
# Out:
# StatementMeta(, bdf0c4f1-3e0a-4c22-b1fd-8e6376c5bbc3, 46, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e7abd638-0b96-4447-832c-421d14ff2998)

# %%
df_with_r = rank_processor.apply_rank(partition_by=["country_name"], order_by=["magnitude"])
display(df_with_r)
# Out:
# StatementMeta(, bdf0c4f1-3e0a-4c22-b1fd-8e6376c5bbc3, 45, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e119b089-cea0-4635-8279-e5bbcb1f76e0)

# %%
df_with_rn = rank_processor.apply_row_number(partition_by=["country_name"], order_by=["magnitude"])
display(df_with_rn)
# Out:
# StatementMeta(, bdf0c4f1-3e0a-4c22-b1fd-8e6376c5bbc3, 48, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1fc0fbf5-ee73-4a2d-ae9e-ff2b3cad0775)
